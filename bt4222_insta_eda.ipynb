# %%
import pandas as pd
captions = pd.read_csv('instacap.csv')


# captions['captions'] = [x.strip('()').split(',') for x in captions['captions']]
captions['captions'] = captions['captions'].str.strip('[]').str.split(',')
captions["emoji"] = ""
captions["mentions"] = ""
captions["hashtags"] = ""
captions["url"] = ""
captions = captions.explode('captions').reset_index()
captions['captions'][4]
captions['clean_captions'] = ''
captions
# Out:
#       index  Unnamed: 0   username  \
# 0         0           0  getlostsg
# 1         0           0  getlostsg
# 2         0           0  getlostsg
# 3         0           0  getlostsg
# 4         0           0  getlostsg
# ...     ...         ...        ...
# 6829    119         119    anne.ng
# 6830    119         119    anne.ng
# 6831    119         119    anne.ng
# 6832    119         119    anne.ng
# 6833    119         119    anne.ng
#
#                                                captions  is_fake emoji  \
# 0       "Finally filming with @outcastssg !! Faster say      0.0
# 1      who do ya'll think will win??\n\nKeep a look ...      0.0
# 2      we have some behind the scenes footage for yo...      0.0
# 3                     'Totally did not push back a post      0.0
# 4      just because we missed the upload time👀 TOTAL...      0.0
# ...                                                 ...      ...   ...
# 6829   'missing my mango ice cream and pigging out w...      0.0
# 6830                      'san‰∏™‰∫∫ at bu‰∏â ü§¢ü§¢'      0.0
# 6831                 'i miss ming ming cart noodle bar'      0.0
# 6832   'ÊÅ≠ÂñúÂèëË¥¢!!! üçäüçäüçä pigging out on ...      0.0
# 6833   'ate so much that i may have gained 12kg too!!!'      0.0
#
#      mentions hashtags url clean_captions
# 0
# 1
# 2
# 3
# 4
# ...       ...      ...  ..            ...
# 6829
# 6830
# 6831
# 6832
# 6833
#
# [6834 rows x 10 columns]

# %%
# import re
# for word in range(len(captions)):
#     pattern = '[0-9]'
#     tweet_clean = captions['captions'][word].split(' ')
#     tweet_clean = [re.sub(pattern, '', i) for i in tweet_clean]
#     tweet_clean = [re.sub("\d*\.\d+","", i) for i in tweet_clean]
#     new_tweet = " ".join(tweet_clean)
#     captions['clean_captions'][word] = new_tweet

# %%
import re
import pandas as pd
for word in range(len(captions)):
    cap = captions["captions"][word]
    if type(cap) == float:
        cap = ""
    word_list = cap.split(' ')
    word_list2 = [re.sub('[0-9]', ' ', i) for i in word_list]
    word_list3 = [re.sub("\d*\.\d+", " ", i) for i in word_list2]
    word_list4 = [str(i).replace('\n', ' ') for i in word_list3]
    word_list5 = [str(i).replace('\\n\\n', ' ') for i in word_list4]
    word_list6 = [str(i).replace('\\n', ' ') for i in word_list5]
    regex = "#(\w+)"
    hashtag_list = re.findall(regex, cap)
    hashtag_list_lower = [item.lower() for item in hashtag_list]
    new_caption = " ".join(word_list6)
    ls = new_caption.split(' ')
    for i in ls.copy():
        if i.startswith('#'):
            ls.remove(i) 
    new_caption = " ".join(ls)
    captions["clean_captions"][word] = new_caption
    captions["hashtags"][word] = hashtag_list
captions[:200]
# Out:
# /var/folders/cw/msb46c3s00b97g2_cw34t0100000gn/T/ipykernel_51909/4291107027.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   captions["clean_captions"][word] = new_caption
# /var/folders/cw/msb46c3s00b97g2_cw34t0100000gn/T/ipykernel_51909/4291107027.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   captions["hashtags"][word] = hashtag_list
#      index  Unnamed: 0   username  \
# 0        0           0  getlostsg
# 1        0           0  getlostsg
# 2        0           0  getlostsg
# 3        0           0  getlostsg
# 4        0           0  getlostsg
# ..     ...         ...        ...
# 195      1           1    ryanxgo
# 196      2           2     sgagsg
# 197      2           2     sgagsg
# 198      2           2     sgagsg
# 199      2           2     sgagsg
#
#                                               captions  is_fake emoji  \
# 0      "Finally filming with @outcastssg !! Faster say      0.0
# 1     who do ya'll think will win??\n\nKeep a look ...      0.0
# 2     we have some behind the scenes footage for yo...      0.0
# 3                    'Totally did not push back a post      0.0
# 4     just because we missed the upload time👀 TOTAL...      0.0
# ..                                                 ...      ...   ...
# 195   'Every short friend needs a shorter friend\n📸...      0.0
# 196           'remember to keep ur fam & friends close      0.0
# 197   but ur charger closer ❤️\n\n#battery #phone #...      0.0
# 198     'Me all day: 😴😪\n\nMe the moment I’m home: 🔥🕺'      0.0
# 199                                               'Wah      0.0
#
#     mentions                                           hashtags url  \
# 0                                                            []
# 1                                                            []
# 2                                                            []
# 3                                                            []
# 4                                                            []
# ..       ...                                                ...  ..
# 195                                                          []
# 196                                                          []
# 197           [battery, phone, psycho, singapore, igsg, sgti...
# 198                                                          []
# 199                                                          []
#
#                                         clean_captions
# 0      "Finally filming with @outcastssg !! Faster say
# 1     who do ya'll think will win?? Keep a look out...
# 2     we have some behind the scenes footage for yo...
# 3                    'Totally did not push back a post
# 4     just because we missed the upload time👀 TOTAL...
# ..                                                 ...
# 195   'Every short friend needs a shorter friend 📸:...
# 196           'remember to keep ur fam & friends close
# 197                     but ur charger closer ❤️
# 198        'Me all day: 😴😪 Me the moment I’m home: 🔥🕺'
# 199                                               'Wah
#
# [200 rows x 10 columns]

# %%
#take out mentions
for word in range(len(captions)):
    cap = captions["clean_captions"][word]
    word_list = cap.split(' ')
    regex = "@(\w+)"
    mention_list = re.findall(regex, cap)
    mention_list_lower = [item.lower() for item in mention_list]
    new_caption = " ".join(word_list)
    ls = new_caption.split(' ')
    for i in ls.copy():
        if i.startswith('@'):
            ls.remove(i) 
    new_caption = " ".join(ls)
    captions["clean_captions"][word] = new_caption
    captions["mentions"][word] = mention_list
captions[:200]
# Out:
# /var/folders/cw/msb46c3s00b97g2_cw34t0100000gn/T/ipykernel_51909/1676476268.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   captions["clean_captions"][word] = new_caption
# /var/folders/cw/msb46c3s00b97g2_cw34t0100000gn/T/ipykernel_51909/1676476268.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   captions["mentions"][word] = mention_list
#      index  Unnamed: 0   username  \
# 0        0           0  getlostsg
# 1        0           0  getlostsg
# 2        0           0  getlostsg
# 3        0           0  getlostsg
# 4        0           0  getlostsg
# ..     ...         ...        ...
# 195      1           1    ryanxgo
# 196      2           2     sgagsg
# 197      2           2     sgagsg
# 198      2           2     sgagsg
# 199      2           2     sgagsg
#
#                                               captions  is_fake emoji  \
# 0      "Finally filming with @outcastssg !! Faster say      0.0
# 1     who do ya'll think will win??\n\nKeep a look ...      0.0
# 2     we have some behind the scenes footage for yo...      0.0
# 3                    'Totally did not push back a post      0.0
# 4     just because we missed the upload time👀 TOTAL...      0.0
# ..                                                 ...      ...   ...
# 195   'Every short friend needs a shorter friend\n📸...      0.0
# 196           'remember to keep ur fam & friends close      0.0
# 197   but ur charger closer ❤️\n\n#battery #phone #...      0.0
# 198     'Me all day: 😴😪\n\nMe the moment I’m home: 🔥🕺'      0.0
# 199                                               'Wah      0.0
#
#             mentions                                           hashtags url  \
# 0       [outcastssg]                                                 []
# 1       [outcastssg]                                                 []
# 2                 []                                                 []
# 3                 []                                                 []
# 4                 []                                                 []
# ..               ...                                                ...  ..
# 195  [cherylenechan]                                                 []
# 196               []                                                 []
# 197               []  [battery, phone, psycho, singapore, igsg, sgti...
# 198               []                                                 []
# 199               []                                                 []
#
#                                         clean_captions
# 0                  "Finally filming with !! Faster say
# 1     who do ya'll think will win?? Keep a look out...
# 2     we have some behind the scenes footage for yo...
# 3                    'Totally did not push back a post
# 4     just because we missed the upload time👀 TOTAL...
# ..                                                 ...
# 195      'Every short friend needs a shorter friend 📸:
# 196           'remember to keep ur fam & friends close
# 197                     but ur charger closer ❤️
# 198        'Me all day: 😴😪 Me the moment I’m home: 🔥🕺'
# 199                                               'Wah
#
# [200 rows x 10 columns]

# %%
#take out url
for word in range(len(captions)):
    cap = captions["clean_captions"][word]
    word_list = cap.split(' ')
    regex = '(?:(?:https?|ftp):\/\/)?[\w/\-?=%.]+\.[\w/\-&?=%.]+'
    url_list = re.findall(regex, cap)
    url_list_lower = [item.lower() for item in url_list]
    new_caption = " ".join(word_list)
    ls = new_caption.split(' ')
    for i in ls.copy():
        if i in url_list_lower:
            ls.remove(i) 
    new_caption = " ".join(ls)
    captions["clean_captions"][word] = new_caption
    captions["url"][word] = url_list
captions[:200]
# Out:
# /var/folders/cw/msb46c3s00b97g2_cw34t0100000gn/T/ipykernel_51909/1434951676.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   captions["clean_captions"][word] = new_caption
# /var/folders/cw/msb46c3s00b97g2_cw34t0100000gn/T/ipykernel_51909/1434951676.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   captions["url"][word] = url_list
#      index  Unnamed: 0   username  \
# 0        0           0  getlostsg
# 1        0           0  getlostsg
# 2        0           0  getlostsg
# 3        0           0  getlostsg
# 4        0           0  getlostsg
# ..     ...         ...        ...
# 195      1           1    ryanxgo
# 196      2           2     sgagsg
# 197      2           2     sgagsg
# 198      2           2     sgagsg
# 199      2           2     sgagsg
#
#                                               captions  is_fake emoji  \
# 0      "Finally filming with @outcastssg !! Faster say      0.0
# 1     who do ya'll think will win??\n\nKeep a look ...      0.0
# 2     we have some behind the scenes footage for yo...      0.0
# 3                    'Totally did not push back a post      0.0
# 4     just because we missed the upload time👀 TOTAL...      0.0
# ..                                                 ...      ...   ...
# 195   'Every short friend needs a shorter friend\n📸...      0.0
# 196           'remember to keep ur fam & friends close      0.0
# 197   but ur charger closer ❤️\n\n#battery #phone #...      0.0
# 198     'Me all day: 😴😪\n\nMe the moment I’m home: 🔥🕺'      0.0
# 199                                               'Wah      0.0
#
#             mentions                                           hashtags url  \
# 0       [outcastssg]                                                 []  []
# 1       [outcastssg]                                                 []  []
# 2                 []                                                 []  []
# 3                 []                                                 []  []
# 4                 []                                                 []  []
# ..               ...                                                ...  ..
# 195  [cherylenechan]                                                 []  []
# 196               []                                                 []  []
# 197               []  [battery, phone, psycho, singapore, igsg, sgti...  []
# 198               []                                                 []  []
# 199               []                                                 []  []
#
#                                         clean_captions
# 0                  "Finally filming with !! Faster say
# 1     who do ya'll think will win?? Keep a look out...
# 2     we have some behind the scenes footage for yo...
# 3                    'Totally did not push back a post
# 4     just because we missed the upload time👀 TOTAL...
# ..                                                 ...
# 195      'Every short friend needs a shorter friend 📸:
# 196           'remember to keep ur fam & friends close
# 197                     but ur charger closer ❤️
# 198        'Me all day: 😴😪 Me the moment I’m home: 🔥🕺'
# 199                                               'Wah
#
# [200 rows x 10 columns]

# %%
#take out emojis
import demoji
import emoji

def remove_emoji(string):
    return emoji.get_emoji_regexp().sub(u'', string)

for word in range(len(captions)):
    cap = captions["clean_captions"][word]
    word_list = cap.split(' ')
    emoji_list = demoji.findall(cap)
    new_caption = " ".join(word_list)
    ls = new_caption.split(' ')
    ls = [demoji.replace(i, "") for i in ls]
    new_caption = " ".join(ls)
    captions["clean_captions"][word] = new_caption
    captions["emoji"][word] = emoji_list
captions[:200]
# Out:
# /var/folders/cw/msb46c3s00b97g2_cw34t0100000gn/T/ipykernel_51909/1151689474.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   captions["clean_captions"][word] = new_caption
# /var/folders/cw/msb46c3s00b97g2_cw34t0100000gn/T/ipykernel_51909/1151689474.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   captions["emoji"][word] = emoji_list
#      index  Unnamed: 0   username  \
# 0        0           0  getlostsg
# 1        0           0  getlostsg
# 2        0           0  getlostsg
# 3        0           0  getlostsg
# 4        0           0  getlostsg
# ..     ...         ...        ...
# 195      1           1    ryanxgo
# 196      2           2     sgagsg
# 197      2           2     sgagsg
# 198      2           2     sgagsg
# 199      2           2     sgagsg
#
#                                               captions  is_fake  \
# 0      "Finally filming with @outcastssg !! Faster say      0.0
# 1     who do ya'll think will win??\n\nKeep a look ...      0.0
# 2     we have some behind the scenes footage for yo...      0.0
# 3                    'Totally did not push back a post      0.0
# 4     just because we missed the upload time👀 TOTAL...      0.0
# ..                                                 ...      ...
# 195   'Every short friend needs a shorter friend\n📸...      0.0
# 196           'remember to keep ur fam & friends close      0.0
# 197   but ur charger closer ❤️\n\n#battery #phone #...      0.0
# 198     'Me all day: 😴😪\n\nMe the moment I’m home: 🔥🕺'      0.0
# 199                                               'Wah      0.0
#
#                                                  emoji         mentions  \
# 0                                                   {}     [outcastssg]
# 1                                        {'👀': 'eyes'}     [outcastssg]
# 2    {'👆🏻': 'backhand index pointing up: light skin...               []
# 3                                                   {}               []
# 4                                        {'👀': 'eyes'}               []
# ..                                                 ...              ...
# 195                         {'📸': 'camera with flash'}  [cherylenechan]
# 196                                                 {}               []
# 197                                {'❤️': 'red heart'}               []
# 198  {'😴': 'sleeping face', '🔥': 'fire', '😪': 'slee...               []
# 199                                                 {}               []
#
#                                               hashtags url  \
# 0                                                   []  []
# 1                                                   []  []
# 2                                                   []  []
# 3                                                   []  []
# 4                                                   []  []
# ..                                                 ...  ..
# 195                                                 []  []
# 196                                                 []  []
# 197  [battery, phone, psycho, singapore, igsg, sgti...  []
# 198                                                 []  []
# 199                                                 []  []
#
#                                         clean_captions
# 0                  "Finally filming with !! Faster say
# 1     who do ya'll think will win?? Keep a look out...
# 2     we have some behind the scenes footage for yo...
# 3                    'Totally did not push back a post
# 4     just because we missed the upload time TOTALL...
# ..                                                 ...
# 195       'Every short friend needs a shorter friend :
# 196           'remember to keep ur fam & friends close
# 197                       but ur charger closer
# 198            'Me all day:  Me the moment I’m home: '
# 199                                               'Wah
#
# [200 rows x 10 columns]

# %%
captions
# Out:
#       index  Unnamed: 0   username  \
# 0         0           0  getlostsg
# 1         0           0  getlostsg
# 2         0           0  getlostsg
# 3         0           0  getlostsg
# 4         0           0  getlostsg
# ...     ...         ...        ...
# 6829    119         119    anne.ng
# 6830    119         119    anne.ng
# 6831    119         119    anne.ng
# 6832    119         119    anne.ng
# 6833    119         119    anne.ng
#
#                                                captions  is_fake  \
# 0       "Finally filming with @outcastssg !! Faster say      0.0
# 1      who do ya'll think will win??\n\nKeep a look ...      0.0
# 2      we have some behind the scenes footage for yo...      0.0
# 3                     'Totally did not push back a post      0.0
# 4      just because we missed the upload time👀 TOTAL...      0.0
# ...                                                 ...      ...
# 6829   'missing my mango ice cream and pigging out w...      0.0
# 6830                      'san‰∏™‰∫∫ at bu‰∏â ü§¢ü§¢'      0.0
# 6831                 'i miss ming ming cart noodle bar'      0.0
# 6832   'ÊÅ≠ÂñúÂèëË¥¢!!! üçäüçäüçä pigging out on ...      0.0
# 6833   'ate so much that i may have gained 12kg too!!!'      0.0
#
#                                                   emoji      mentions  \
# 0                                                    {}  [outcastssg]
# 1                                         {'👀': 'eyes'}  [outcastssg]
# 2     {'👆🏻': 'backhand index pointing up: light skin...            []
# 3                                                    {}            []
# 4                                         {'👀': 'eyes'}            []
# ...                                                 ...           ...
# 6829                                 {'©': 'copyright'}            []
# 6830                                {'™': 'trade mark'}            []
# 6831                                                 {}            []
# 6832                                                 {}            []
# 6833                                                 {}            []
#
#      hashtags url                                     clean_captions
# 0          []  []                "Finally filming with !! Faster say
# 1          []  []   who do ya'll think will win?? Keep a look out...
# 2          []  []   we have some behind the scenes footage for yo...
# 3          []  []                  'Totally did not push back a post
# 4          []  []   just because we missed the upload time TOTALL...
# ...       ...  ..                                                ...
# 6829       []  []   'missing my mango ice cream and pigging out w...
# 6830       []  []                       'san‰∏‰∫∫ at bu‰∏â ü§¢ü§¢'
# 6831       []  []                 'i miss ming ming cart noodle bar'
# 6832       []  []   'ÊÅ≠ÂñúÂèëË¥¢!!! üçäüçäüçä pigging out on ...
# 6833       []  []   'ate so much that i may have gained   kg too!!!'
#
# [6834 rows x 10 columns]
